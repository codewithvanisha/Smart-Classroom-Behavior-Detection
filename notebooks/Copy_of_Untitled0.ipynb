# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Classroom', 'Saved from the Google app', 'archive.zip.zip', 'Smart_Classroom_Project.ipynb', 'best.pt', 'train-2', 'Colab Notebooks']

# %%
import zipfile

zip_path = "/content/drive/MyDrive/archive.zip.zip"
extract_path = "/content/dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted successfully!")
# Out:
# Dataset extracted successfully!

# %%
import os

for root, dirs, files in os.walk("/content/dataset"):
    if "data.yaml" in files:
        print("Dataset found at:")
        print(root)
# Out:
# Dataset found at:
# /content/dataset/archive

# %%
import os

print(os.listdir("/content/dataset/archive"))
# Out:
# ['data.yaml', 'test', 'train', 'valid']

# %%
import os

train_images = len(os.listdir(f"{"/content/dataset/archive"}/train/images"))
valid_images = len(os.listdir(f"{"/content/dataset/archive"}/valid/images"))
test_images = len(os.listdir(f"{"/content/dataset/archive"}/test/images"))

total_images = train_images + valid_images + test_images

print("Train Images:", train_images)
print("Valid Images:", valid_images)
print("Test Images:", test_images)
print("Total Images:", total_images)
# Out:
# Train Images: 14516
# Valid Images: 2278
# Test Images: 1140
# Total Images: 17934

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")

metrics = model.val()

print(metrics)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2034/1978960339.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 model = YOLO("/content/drive/MyDrive/best.pt")
#       4
#       5 metrics = model.val()
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 6.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
print("Ultralytics installed successfully!")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics installed successfully!

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")
print("Model loaded successfully!")
# Out:
# Model loaded successfully!

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")

metrics = model.val()

print(metrics)
# Out:
# Ultralytics 8.4.66 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2034/1978960339.py in <cell line: 0>()
#       3 model = YOLO("/content/drive/MyDrive/best.pt")
#       4
# ----> 5 metrics = model.val()
#       6
#       7 print(metrics)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in val(self, validator, **kwargs)
#     613
#     614         validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 615         validator(model=self.model)
#     616         self.metrics = validator.metrics
#     617         return validator.metrics
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
# ...

# %%
print(open("/content/dataset/archive/data.yaml").read())
# Out:
# path: archive
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 8
# names:
#   - handrise
#   - read
#   - write
#   - sleep
#   - using_device
#   - stand
#   - look_forward
#   - turn_head

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")

metrics = model.val(
    data="/content/dataset/archive/data.yaml"
)

print(metrics)
# Out:
# Ultralytics 8.4.66 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2034/1436232401.py in <cell line: 0>()
#       3 model = YOLO("/content/drive/MyDrive/best.pt")
#       4
# ----> 5 metrics = model.val(
#       6     data="/content/dataset/archive/data.yaml"
#       7 )
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in val(self, validator, **kwargs)
#     613
#     614         validator = (validator or self._smart_load("validator"))(args=args, _callbacks=self.callbacks)
# --> 615         validator(model=self.model)
#     616         self.metrics = validator.metrics
#     617         return validator.metrics
#
# ...

# %%
with open("/content/dataset/archive/data.yaml", "r") as f:
    print(f.read())
# Out:
# path: archive
# train: train/images
# val: valid/images
# test: test/images
#
# nc: 8
# names:
#   - handrise
#   - read
#   - write
#   - sleep
#   - using_device
#   - stand
#   - look_forward
#   - turn_head

# %%
yaml_text = """
path: /content/dataset/archive
train: train/images
val: valid/images
test: test/images

nc: 8
names:
  - handrise
  - read
  - write
  - sleep
  - using_device
  - stand
  - look_forward
  - turn_head
"""

with open("/content/dataset/archive/data_fixed.yaml", "w") as f:
    f.write(yaml_text)

print("Fixed YAML created!")
# Out:
# Fixed YAML created!

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")

metrics = model.val(
    data="/content/dataset/archive/data_fixed.yaml"
)

print(metrics)
# Out:
# Ultralytics 8.4.66 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1407.8±695.0 MB/s, size: 55.2 KB)
# val: Scanning /content/dataset/archive/valid/labels... 2278 images, 18 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2278/2278 2.0Kit/s 1.1s
# val: New cache created: /content/dataset/archive/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 143/143 4.6s/it 10:54
#                    all       2278      32324      0.805      0.779      0.822      0.524
#               handrise        955       1610      0.792      0.811      0.863      0.546
#                   read       1008       5655       0.82      0.781      0.854      0.532
#                  write        506       1015      0.788      0.835      0.858      0.534
# ...
